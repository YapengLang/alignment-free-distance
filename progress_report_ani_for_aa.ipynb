# %% [markdown]
# # Progress Report of ani
# ## 29/1/23
#
# 1. fit regression models to `ani` and `frac_diff` for a.a.
#
# 2. compare the a.a. trees from `frac_diff` and from estimates of fractional difference by `ani`.
#
# 3. repeat 2. for more data

# %% [markdown]
# ## Setup

# %%
from collections import Counter
from math import log

import numpy
import plotly.express as px
import plotly.graph_objects as go
from cogent3 import load_aligned_seqs
from cogent3.app import io, translate
from cogent3.app.align import progressive_align
from cogent3.phylo import nj
from plotly.subplots import make_subplots
from scipy.optimize import curve_fit

# %%
#function of the relation
def cubic_function(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

def kfreqs(seq, k):
    return Counter([seq[i: i+k] for i in range(len(seq) - k + 1)])

#modify to correct the count#
def diff_freqs(f1: Counter, f2: Counter) -> int:
    # f1 is always smaller
    c = 0
    
    for k in f1:
        d = f1[k] - f2[k] 
        if d > 0:
            c += d
    
    return c

def ani(s1, s2, k):
    
    s1, s2 = (s1, s2) if len(s1) < len(s2) else (s2, s1)
    f1 = kfreqs(s1, k)
    f2 = kfreqs(s2, k)
    delta = diff_freqs(f1, f2)
    return  delta / k / len(s1)


#update to get the ani matrix
def pair_ani(seq_coll:dict, pair_distance, k) -> numpy.ndarray: 
    """
    Get a pairwise ani distance matrix. 
    """
    seq_names = pair_distance.names
    num_seqs = len(seq_names)
    anis = numpy.zeros((num_seqs, num_seqs), dtype=float)

    #calculate ani matrix
    for x in range(num_seqs-1):
        name1 = seq_names[x]
        for y in range(x + 1, num_seqs):
            name2 = seq_names[y]
            dist = ani(seq_coll[name1], seq_coll[name2], k) 
            anis[x,y] = dist
            anis[y,x] = dist
            

    return anis


#tree construction
def nj_Kimura_corr_frac(distance_matrix): 
    """
    should return a PhyloNode class, which constructed by corrected fractional difference.
    """
    names = distance_matrix.names
    num_seqs = distance_matrix.shape[0]
    indices = numpy.tril_indices(num_seqs)

    array_distance = distance_matrix.to_array()
    dist_frac_diff = {}
    for i in indices[0]:
        for j in indices[1]:
            frac_diff = array_distance[i][j] 
            #Kimura correction
            dist_frac_diff[(names[i], names[j])] =  -log(1- frac_diff - 0.2*frac_diff**2)
    return nj.nj(dist_frac_diff, show_progress=False)

def nj_Kimura_corr_ani(distance_matrix, ani_matrix, parameters): 
    """
    should return a PhyloNode class, which constructed by corrected fractional difference estimates.
    """
    names = distance_matrix.names
    num_seqs = distance_matrix.shape[0]
    indices = numpy.tril_indices(num_seqs)

    array_distance = distance_matrix.to_array()
    dist_estimates = {}
    c = parameters[3]
    for i in indices[0]:
        for j in indices[1]:
            ani = ani_matrix[i][j] 
            #predict frac_diff
            parameters[3] = c - ani
            if abs(ani - cubic_function(min(numpy.real(numpy.roots(parameters))), 
                                  6.96178476e-01, -1.36789855e+00,  9.49234106e-01,  8.45293002e-04)) < 1e-9 :
               estimate_D = min(numpy.real(numpy.roots(parameters)))
            else:
                estimate_D = max(numpy.real(numpy.roots(parameters)))
            #Kimura correction
            dist_estimates[(names[i], names[j])] =  -log(1- estimate_D - 0.2*estimate_D**2)
    return nj.nj(dist_estimates, show_progress=False)

# %%
#load cogent3 test data
aln = load_aligned_seqs("~/repos/Cogent3/tests/data/brca1.fasta", moltype="dna")

# %% [markdown]
# ## Fit an appropriate model to a.a.

# %%
aa_aln = aln.get_translation(incomplete_ok=True, gc=1)

# %%
#calculate fractional difference 
aa_pairwise_distance = aa_aln.distance_matrix()

# %%
aa_seq_coll = aa_aln.degap()
aa_data = aa_seq_coll.to_dict()

# %%
aa_anis_k_2 = pair_ani(aa_data, aa_pairwise_distance, k=2)
aa_anis_k_3 = pair_ani(aa_data, aa_pairwise_distance, k=3)
aa_anis_k_4 = pair_ani(aa_data, aa_pairwise_distance, k=4)
aa_anis_k_5 = pair_ani(aa_data, aa_pairwise_distance, k=5)
aa_anis_k_6 = pair_ani(aa_data, aa_pairwise_distance, k=6)

# %%
#get vectors of ani and pairwise distance for data with gaps
num_seqs = aa_pairwise_distance.shape[0]
indices = numpy.tril_indices(num_seqs)

aa_anis_k_2 = aa_anis_k_2[indices]
aa_anis_k_3 = aa_anis_k_3[indices]
aa_anis_k_4 = aa_anis_k_4[indices]
aa_anis_k_5 = aa_anis_k_5[indices]
aa_anis_k_6 = aa_anis_k_6[indices]

aa_frac_diff = aa_pairwise_distance.array[indices]

# %%
fig = make_subplots(rows=5, cols=1,
x_title="fractional difference", y_title="ani")

fig.add_trace(go.Scatter(
    x=aa_frac_diff,
    y=aa_anis_k_2,
    mode='markers',
    name='k = 2'
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=aa_frac_diff,
    y=aa_anis_k_3,
    mode='markers',
    name='k = 3'
), row=2, col=1)

fig.add_trace(go.Scatter(
    x=aa_frac_diff,
    y=aa_anis_k_4, 
    mode='markers',
    name='k = 4'
), row=3, col=1)

fig.add_trace(go.Scatter(
    x=aa_frac_diff,
    y=aa_anis_k_5, 
    mode='markers',
    name='k = 5'
), row=4, col=1)

fig.add_trace(go.Scatter(
    x=aa_frac_diff,
    y=aa_anis_k_6, 
    mode='markers',
    name='k = 6'
), row=5, col=1)

fig.update_layout(height=1000, width=1000, title_text="Comparison between ANI and fractional difference")
fig.show()

# %%
aa_frac_diff_ordered = numpy.array(sorted(aa_frac_diff)) #cast frac_identical into list to order the data

# %%
#fit data with models to get parameters, for k = 4
aa_popt_cub = curve_fit(cubic_function, aa_frac_diff, aa_anis_k_4)[0]
aa_popt_cub
# Out:
# array([ 6.96178476e-01, -1.36789855e+00,  9.49234106e-01,  8.45293002e-04])

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=aa_frac_diff, y=aa_anis_k_4, mode='markers', name='emprical data'))
fig.add_trace(go.Scatter(x=aa_frac_diff_ordered, y=cubic_function(aa_frac_diff_ordered, *aa_popt_cub), mode='lines', name='fit line'))
fig.add_annotation(x=0.48, y=0.17,
            text="y = 0.696x^3 - 1.368x^2 + 0.949x + 0.001",
            showarrow = False)
fig.update_layout(title='Polynomial models for a.a.',
                   xaxis_title='fractional difference',
                   yaxis_title='ani')
fig.show()

# %% [markdown]
# ## Use brca1 data to construct the tree by ```frac_diff``` estimates

# %%
#after correcting to Kimura protein distance, construct fraction difference tree
tree_frac_diff = nj_Kimura_corr_frac(aa_pairwise_distance)

fig_frac_diff = tree_frac_diff.get_figure(width=800, height=800)
fig_frac_diff.scale_bar = "top right"
fig_frac_diff.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="aae96c5d-7662-4465-a325-bc6ac0b7eb62" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aae96c5d-7662-4465-a325-bc6ac0b7eb62")) {                    Plotly.newPlot(                        "aae96c5d-7662-4465-a325-bc6ac0b7eb62",                        [{"line":{"color":"black","shape":"spline","smoothing":1.3,"width":1.25},"mode":"lines","showlegend":false,"x":[null,null,0,0,null,0,0.0014103287080073565,null,0.0014103287080073565,0.0014103287080073565,null,0.0014103287080073565,0.004526558701550572,null,0.004526558701550572,0.004526558701550572,null,0.004526558701550572,0.006938897347373412,null,0.006938897347373412,0.006938897347373412,null,0.006938897347373412,0.028072947769515164,null,0.028072947769515164,0.028072947769515164,null,0.028072947769515164,0.03302860312189905,null,0.03302860312189905,0.03302860312189905,null,0.03302860312189905,0.05937890561568156,null,0.05937890561568156,0.05937890561568156,null,0.05937890561568156,0.06352246931938635,null,0.06352246931938635,0.06352246931938635,null,0.06352246931938635,0.07788473417691216,null,0.07788473417691216,0.07788473417691216,null,0.07788473417691216,0.17142043456237513,null,0.07788473417691216,0.07788473417691216,null,0.07788473417691216,0.18188383448275539,null,0.06352246931938635,0.06352246931938635,null,0.06352246931938635,0.3863892581113575,null,0.05937890561568156,0.05937890561568156,null,0.05937890561568156,0.18511354545478131,null,0.03302860312189905,0.03302860312189905,null,0.03302860312189905,0.12394119333710747,null,0.12394119333710747,0.12394119333710747,null,0.12394119333710747,0.15732101299025175,null,0.12394119333710747,0.12394119333710747,null,0.12394119333710747,0.2027407768043773,null,0.028072947769515164,0.028072947769515164,null,0.028072947769515164,0.04484305796460117,null,0.04484305796460117,0.04484305796460117,null,0.04484305796460117,0.16587050767639971,null,0.04484305796460117,0.04484305796460117,null,0.04484305796460117,0.18240374006473647,null,0.006938897347373412,0.006938897347373412,null,0.006938897347373412,0.03194527929533954,null,0.03194527929533954,0.03194527929533954,null,0.03194527929533954,0.09873490318249817,null,0.03194527929533954,0.03194527929533954,null,0.03194527929533954,0.11732230235607077,null,0.004526558701550572,0.004526558701550572,null,0.004526558701550572,0.03259989111745985,null,0.03259989111745985,0.03259989111745985,null,0.03259989111745985,0.042715022433748785,null,0.042715022433748785,0.042715022433748785,null,0.042715022433748785,0.05144688616761583,null,0.05144688616761583,0.05144688616761583,null,0.05144688616761583,0.06461244368166938,null,0.06461244368166938,0.06461244368166938,null,0.06461244368166938,0.11225225907913364,null,0.11225225907913364,0.11225225907913364,null,0.11225225907913364,0.1424478348235888,null,0.11225225907913364,0.11225225907913364,null,0.11225225907913364,0.14369197017264138,null,0.06461244368166938,0.06461244368166938,null,0.06461244368166938,0.15528146317586403,null,0.05144688616761583,0.05144688616761583,null,0.05144688616761583,0.2291802296891829,null,0.042715022433748785,0.042715022433748785,null,0.042715022433748785,0.1844642802350999,null,0.03259989111745985,0.03259989111745985,null,0.03259989111745985,0.14670150801977422,null,0.0014103287080073565,0.0014103287080073565,null,0.0014103287080073565,0.0070048523659931835,null,0.0070048523659931835,0.0070048523659931835,null,0.0070048523659931835,0.047376053027899975,null,0.047376053027899975,0.047376053027899975,null,0.047376053027899975,0.15688209899153122,null,0.047376053027899975,0.047376053027899975,null,0.047376053027899975,0.21828579154638977,null,0.0070048523659931835,0.0070048523659931835,null,0.0070048523659931835,0.17196907996097843,null,0,0,null,0,0. ...

# %%
#after predict fraction difference by ani, construct tree
aa_anis_k_4 = pair_ani(aa_data, aa_pairwise_distance, k=4)
tree_ani = nj_Kimura_corr_ani(aa_pairwise_distance, aa_anis_k_4, parameters=aa_popt_cub)

fig_ani = tree_ani.get_figure(width=800, height=800)
fig_ani.scale_bar = "top right"
fig_ani.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="32470bce-0995-4c17-9068-f71d832eeadc" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32470bce-0995-4c17-9068-f71d832eeadc")) {                    Plotly.newPlot(                        "32470bce-0995-4c17-9068-f71d832eeadc",                        [{"line":{"color":"black","shape":"spline","smoothing":1.3,"width":1.25},"mode":"lines","showlegend":false,"x":[null,null,0,0,null,0,0.0028661470873295666,null,0.0028661470873295666,0.0028661470873295666,null,0.0028661470873295666,0.009462151094385349,null,0.009462151094385349,0.009462151094385349,null,0.009462151094385349,0.03203148017441032,null,0.03203148017441032,0.03203148017441032,null,0.03203148017441032,0.1014441491201506,null,0.03203148017441032,0.03203148017441032,null,0.03203148017441032,0.11634462040561916,null,0.009462151094385349,0.009462151094385349,null,0.009462151094385349,0.17263584778080715,null,0.0028661470873295666,0.0028661470873295666,null,0.0028661470873295666,0.03322457359642461,null,0.03322457359642461,0.03322457359642461,null,0.03322457359642461,0.1514828688128132,null,0.03322457359642461,0.03322457359642461,null,0.03322457359642461,0.1947791903707139,null,0,0,null,0,0.0054348465048160224,null,0.0054348465048160224,0.0054348465048160224,null,0.0054348465048160224,0.012525193803064692,null,0.012525193803064692,0.012525193803064692,null,0.012525193803064692,0.02177515895814444,null,0.02177515895814444,0.02177515895814444,null,0.02177515895814444,0.22846289826288718,null,0.02177515895814444,0.02177515895814444,null,0.02177515895814444,0.3182587079112479,null,0.012525193803064692,0.012525193803064692,null,0.012525193803064692,0.03778073332603897,null,0.03778073332603897,0.03778073332603897,null,0.03778073332603897,0.05351839060297092,null,0.05351839060297092,0.05351839060297092,null,0.05351839060297092,0.06082313499559624,null,0.06082313499559624,0.06082313499559624,null,0.06082313499559624,0.0632451630245835,null,0.0632451630245835,0.0632451630245835,null,0.0632451630245835,0.1152173740880482,null,0.1152173740880482,0.1152173740880482,null,0.1152173740880482,0.14565045057919215,null,0.1152173740880482,0.1152173740880482,null,0.1152173740880482,0.15209007892928664,null,0.0632451630245835,0.0632451630245835,null,0.0632451630245835,0.27724679676216024,null,0.06082313499559624,0.06082313499559624,null,0.06082313499559624,0.15555804170913634,null,0.05351839060297092,0.05351839060297092,null,0.05351839060297092,0.17984181381511757,null,0.03778073332603897,0.03778073332603897,null,0.03778073332603897,0.14241748735063348,null,0.0054348465048160224,0.0054348465048160224,null,0.0054348465048160224,0.02371052009119363,null,0.02371052009119363,0.02371052009119363,null,0.02371052009119363,0.0415019291346493,null,0.0415019291346493,0.0415019291346493,null,0.0415019291346493,0.057323777493527225,null,0.057323777493527225,0.057323777493527225,null,0.057323777493527225,0.07650506232101195,null,0.07650506232101195,0.07650506232101195,null,0.07650506232101195,0.1090228041565579,null,0.1090228041565579,0.1090228041565579,null,0.1090228041565579,0.1471724149155728,null,0.1471724149155728,0.1471724149155728,null,0.1471724149155728,0.18774518547359387,null,0.1471724149155728,0.1471724149155728,null,0.1471724149155728,0.22601984918519663,null,0.1090228041565579,0.1090228041565579,null,0.1090228041565579,0.44812419248859997,null,0.07650506232101195,0.07650506232101195,null,0.07650506232101195,0.20747307558706402,null,0.057323777493527225,0.057323777493527225,null,0.057323777493527225,0.20377539063411182,null,0.0415019291346493,0.0415019291346493,null,0.0415019291346493,0.06507666191495655,null,0.06507666191495655,0.06507666191495655,null,0.06507666191495655,0.16856774744661795,null,0.06507666191495655,0.065 ...

# %% [markdown]
# ## Use more emprical data to check fraction identity estimate

# %% [markdown]
# ### Case 1 : SCA1-cds data from cogent3

# %%
#load up
reader = io.load_unaligned(format="fasta")
to_aa = translate.translate_seqs()
process = reader + to_aa
seqs_sca1 = process("~/repos/Cogent3/doc/data/SCA1-cds.fasta")

aa_aligner = progressive_align("protein")
aligned = aa_aligner(seqs_sca1)
aligned
# Out:
# 6 x 825 alignment: Human[MKSNQERSNEC...], Chimp[MKSNQERSNEC...], Mouse Lemur[MKSNQERSNEC...], ...

# %%
#compute fractional difference
pairwise_distance_sca1 = aligned.distance_matrix()
pairwise_distance_sca1
# Out:
# =============================================================================
# names           Chimp     Human    Macaque     Mouse    Mouse Lemur       Rat
# -----------------------------------------------------------------------------
# Chimp          0.0000    0.0050     0.0112    0.1093         0.0799    0.1056
# Human          0.0050    0.0000     0.0075    0.1052         0.0759    0.1015
# Macaque        0.0112    0.0075     0.0000    0.1027         0.0772    0.0990
# Mouse          0.1093    0.1052     0.1027    0.0000         0.1090    0.0203
# Mouse Lemur    0.0799    0.0759     0.0772    0.1090         0.0000    0.1028
# Rat            0.1056    0.1015     0.0990    0.0203         0.1028    0.0000
# -----------------------------------------------------------------------------

# %%
#compute ani
aa_seq_coll_sca1 = aligned.degap()
data_sca1 = aa_seq_coll_sca1.to_dict()
aa_anis_k_4_sca1 = pair_ani(data_sca1, pairwise_distance_sca1, k=4)

# %%
#after correcting to Kimura distance, construct fraction difference tree
tree_frac_diff_sca1 = nj_Kimura_corr_frac(pairwise_distance_sca1)

fig_frac_diff_sca1 = tree_frac_diff_sca1.get_figure(width=500, height=500)
fig_frac_diff_sca1.scale_bar = "top right"
fig_frac_diff_sca1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e55972af-eb11-4e86-9b7c-96906c92438d" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e55972af-eb11-4e86-9b7c-96906c92438d")) {                    Plotly.newPlot(                        "e55972af-eb11-4e86-9b7c-96906c92438d",                        [{"line":{"color":"black","shape":"spline","smoothing":1.3,"width":1.25},"mode":"lines","showlegend":false,"x":[null,null,0,0,null,0,0.0031767982743306084,null,0,0,null,0,0.0037662860803000728,null,0.0037662860803000728,0.0037662860803000728,null,0.0037662860803000728,0.004143470844875791,null,0.0037662860803000728,0.0037662860803000728,null,0.0037662860803000728,0.008362993762677573,null,0,0,null,0,0.03469409137959676,null,0.03469409137959676,0.03469409137959676,null,0.03469409137959676,0.07697451329955837,null,0.03469409137959676,0.03469409137959676,null,0.03469409137959676,0.09658073883085286,null,0.09658073883085286,0.09658073883085286,null,0.09658073883085286,0.1043534400224787,null,0.09658073883085286,0.09658073883085286,null,0.09658073883085286,0.10937926202271758,null],"y":[null,null,1.3,3.25,null,3.25,3.25,null,1.3,1.3,null,1.3,1.3,null,1.3,1.9500000000000002,null,1.9500000000000002,1.9500000000000002,null,1.3,0.65,null,0.65,0.65,null,1.3,-1.625,null,-1.625,-1.625,null,-1.625,-0.65,null,-0.65,-0.65,null,-1.625,-2.6,null,-2.6,-2.6,null,-2.6,-1.9500000000000002,null,-1.9500000000000002,-1.9500000000000002,null,-2.6,-3.25,null,-3.25,-3.25,null],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"black","size":3,"symbol":"circle"},"mode":"markers","showlegend":false,"text":["root","Macaque","edge.2","Human","Chimp","edge.1","Mouse Lemur","edge.0","Rat","Mouse"],"x":[0,0.0031767982743306084,0.0037662860803000728,0.004143470844875791,0.008362993762677573,0.03469409137959676,0.07697451329955837,0.09658073883085286,0.1043534400224787,0.10937926202271758],"y":[1.3,3.25,1.3,1.9500000000000002,0.65,-1.625,-0.65,-2.6,-1.9500000000000002,-3.25],"type":"scatter"}],                        {"annotations":[{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Macaque","textangle":0,"x":0.005911279824898548,"xanchor":"left","xref":"x","y":3.25,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Human","textangle":0,"x":0.00687795239544373,"xanchor":"left","xref":"x","y":1.9500000000000002,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Chimp","textangle":0,"x":0.011097475313245512,"xanchor":"left","xref":"x","y":0.65,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Mouse Lemur","textangle":0,"x":0.07970899485012631,"xanchor":"left","xref":"x","y":-0.65,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Rat","textangle":0,"x":0.10708792157304664,"xanchor":"left","xref":"x","y":-1.9500000000000002,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Mouse","textangle":0,"x":0.11211374357328552,"xanchor":"left","xref":"x","y":-3.25,"yref":"y"},{"ax":0,"ay":0,"showarrow":false,"text":"0.01","x":0.11484822512385347,"xref":"x","y":3.840909090909091,"yref":"y","yshift":10}],"autosize":true,"font":{"family":"Balto","size":14},"height":500,"hovermode":"closest","margin":{"b":50,"l":50,"pad":4,"r":50,"t":50},"shapes":[{"line":{"color":"black","width":1.25},"name":"scale_bar","type":"line","x0":0.10937926202271758,"x1":0.12031718822498934,"y0":3.840909090909091,"y1":3.840909090909091}],"showlegend":false,"width":500,"xaxis":{"visible":false},"yaxis":{"visible":false},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","wi ...

# %%
#after predict fraction identity by ani, construct tree
tree_ani_sca1 = nj_Kimura_corr_ani(pairwise_distance_sca1, aa_anis_k_4_sca1, parameters=aa_popt_cub)

fig_ani_sca1 = tree_ani_sca1.get_figure(width=500, height=500)
fig_ani_sca1.scale_bar = "top right"
fig_ani_sca1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f283b36d-460b-41d1-9e57-3ab18d0737dc" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f283b36d-460b-41d1-9e57-3ab18d0737dc")) {                    Plotly.newPlot(                        "f283b36d-460b-41d1-9e57-3ab18d0737dc",                        [{"line":{"color":"black","shape":"spline","smoothing":1.3,"width":1.25},"mode":"lines","showlegend":false,"x":[null,null,0,0,null,0,0.0035836460790043684,null,0.0035836460790043684,0.0035836460790043684,null,0.0035836460790043684,1.0035836460790044,null,0.0035836460790043684,0.0035836460790043684,null,0.0035836460790043684,0.007355405499244128,null,0,0,null,0,0.004036225460553017,null,0,0,null,0,0.03263304131285539,null,0.03263304131285539,0.03263304131285539,null,0.03263304131285539,0.06818289051468371,null,0.03263304131285539,0.03263304131285539,null,0.03263304131285539,0.083426346850053,null,0.083426346850053,0.083426346850053,null,0.083426346850053,0.08955819284472627,null,0.083426346850053,0.083426346850053,null,0.083426346850053,0.09762466430436809,null],"y":[null,null,0.65,2.6,null,2.6,2.6,null,2.6,3.25,null,3.25,3.25,null,2.6,1.9500000000000002,null,1.9500000000000002,1.9500000000000002,null,0.65,0.65,null,0.65,0.65,null,0.65,-1.625,null,-1.625,-1.625,null,-1.625,-0.65,null,-0.65,-0.65,null,-1.625,-2.6,null,-2.6,-2.6,null,-2.6,-1.9500000000000002,null,-1.9500000000000002,-1.9500000000000002,null,-2.6,-3.25,null,-3.25,-3.25,null],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"black","size":3,"symbol":"circle"},"mode":"markers","showlegend":false,"text":["root","edge.2","Human","Chimp","Macaque","edge.1","Mouse Lemur","edge.0","Rat","Mouse"],"x":[0,0.0035836460790043684,1.0035836460790044,0.007355405499244128,0.004036225460553017,0.03263304131285539,0.06818289051468371,0.083426346850053,0.08955819284472627,0.09762466430436809],"y":[0.65,2.6,3.25,1.9500000000000002,0.65,-1.625,-0.65,-2.6,-1.9500000000000002,-3.25],"type":"scatter"}],                        {"annotations":[{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Human","textangle":0,"x":1.0286732372309795,"xanchor":"left","xref":"x","y":3.25,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Chimp","textangle":0,"x":0.03244499665121924,"xanchor":"left","xref":"x","y":1.9500000000000002,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Macaque","textangle":0,"x":0.029125816612528128,"xanchor":"left","xref":"x","y":0.65,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Mouse Lemur","textangle":0,"x":0.09327248166665882,"xanchor":"left","xref":"x","y":-0.65,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Rat","textangle":0,"x":0.11464778399670138,"xanchor":"left","xref":"x","y":-1.9500000000000002,"yref":"y"},{"font":{"family":"Inconsolata, monospace","size":12},"showarrow":false,"text":"Mouse","textangle":0,"x":0.1227142554563432,"xanchor":"left","xref":"x","y":-3.25,"yref":"y"},{"ax":0,"ay":0,"showarrow":false,"text":"0.10","x":1.0537628283829545,"xref":"x","y":3.840909090909091,"yref":"y","yshift":10}],"autosize":true,"font":{"family":"Balto","size":14},"height":500,"hovermode":"closest","margin":{"b":50,"l":50,"pad":4,"r":50,"t":50},"shapes":[{"line":{"color":"black","width":1.25},"name":"scale_bar","type":"line","x0":1.0035836460790044,"x1":1.103942010686905,"y0":3.840909090909091,"y1":3.840909090909091}],"showlegend":false,"width":500,"xaxis":{"visible":false},"yaxis":{"visible":false},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"f ...

# %%
#do MSA using ani tree as a guide
aligner = progressive_align("protein", guide_tree=tree_ani_sca1)
aligned = aligner(seqs_sca1)
aligned
# Out:
# 6 x 825 alignment: Mouse Lemur[MKSNQERSNEC...], Rat[MKSNQERSNEC...], Mouse[MKSNQERSNEC...], ...

# %% [markdown]
# ### Case 2 : Transcriptome data of turtle, bird, crocodiles from Chiari et al. 2012

# %%
#load data
aln_turtle = load_aligned_seqs("~/Documents/lab/alignment-free/data/turtle.fasta", moltype="dna")

#get translated
aa_aln_turtle = aln_turtle.get_translation(incomplete_ok=True, gc=1)

# %%
#compute fractional difference
aa_pair_distance_turtle = aa_aln_turtle.distance_matrix()
aa_pair_distance_turtle
# Out:
# =======================================================================================================================================================================================================================================
# names                Anolis    Gallus      Homo    Monodelphis    Ornithorhynchus    Taeniopygia    Xenopus    alligator    caiman    caretta    chelonoidis_nigra    emys_orbicularis    phrynops    podarcis    protopterus    python
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Anolis               0.0000    0.1157    0.1461         0.1507             0.1504         0.1157     0.1834       0.0979    0.1204     0.1004               0.0763              0.1180      0.1212      0.0363         0.1587    0.0666
# Gallus               0.1157    0.0000    0.1286         0.1387             0.1341         0.0434     0.1779       0.0591    0.0873     0.0847               0.0664              0.0863      0.0875      0.0787         0.1452    0.0990
# Homo                 0.1461    0.1286    0.0000         0.0981             0.1127         0.1249     0.1893       0.0953    0.1462     0.1225               0.0916              0.1248      0.1252      0.1284         0.1501    0.1172
# Monodelphis          0.1507    0.1387    0.0981         0.0000             0.1185         0.1377     0.1931       0.0998    0.1483     0.1295               0.0856              0.1298      0.1384      0.1310         0.1578    0.1321
# Ornithorhynchus      0.1504    0.1341    0.1127         0.1185             0.0000         0.1337     0.1961       0.1043    0.1571     0.1141               0.0841              0.1267      0.1285      0.1199         0.1584    0.1097
# Taeniopygia          0.1157    0.0434    0.1249         0.1377             0.1337         0.0000     0.1790       0.0698    0.0852     0.0849               0.0665              0.0941      0.0931      0.0748         0.1431    0.0983
# Xenopus              0.1834    0.1779    0.1893         0.1931             0.1961         0.1790     0.0000       0.1565    0.1914     0.1621               0.1400              0.1828      0.1930      0.1488         0.1530    0.1629
# alligator            0.0979    0.0591    0.0953         0.0998             0.1043         0.0698     0.1565       0.0000    0.0062     0.0486               0.0434              0.0707      0.0578      0.0349         0.1071    0.0902
# caiman               0.1204    0.0873    0.1462         0.1483             0.1571         0.0852     0.1914       0.0062    0.0000     0.0833               0.0506              0.0689      0.0677      0.1003         0.1450    0.1026
# caretta              0.1004    0.0847    0.1225         0.1295             0.1141         0.0849     0.1621       0.0486    0.0833     0.0000               0.0094              0.0076      0.0270      0.0693         0.1165    0.0790
# chelonoidis_nigra    0.0763    0.0664    0.0916         0.0856             0.0841         0.0665     0.1400       0.0434    0.0506     0.0094               0.0000              0.0097      0.0304      0.0541         0.1054    0.0723
# emys_orbicularis     0.1180    0.0863    0.1248         0.1298             0.1267         0.0941     0.1828       0.0707    0.0689     0.0076               0.0097              0.0000      0.0324      0.0614         0.1481    0.0650
# phrynops             0.1212    0.0875    0.1252         0.1384             0.1285         0.0931     0.1930       0.0578    0.0677     0.0270               0.0304              0.0324      0.0000      0.0692         0.1709    0.0790
# podarcis             0.0363    0.0787    0.1284         0.1310             0.1199         0.0748     0.1488       0.0349    0.1003     0.0693               0.0541              0.0614      0.0692      0.0000         0.1653    0.0329
# protopterus          0.1587    0.1452    0.1501         0.1578             0.1584         0.1431     0.1530       0.1071    0.1450     0.1165               0.1054              0.1481      0.1709      0.1653         0.0000    0.1186
# python               0.0666    0.0990    0.1172         0.1321             0.1097         0.0983     0.1629       0.0902    0.1026     0.0790               0.0723              0.0650      0.0790      0.0329         0.1186    0.0000
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#compute ani 
aa_seq_coll_turtle = aa_aln_turtle.degap()
aa_data_turtle = aa_seq_coll_turtle.to_dict()

aa_anis_k_4_turtle = pair_ani(aa_data_turtle, aa_pair_distance_turtle, k=4)

# %%
#after correcting to Kimura distance, construct fraction difference tree
tree_frac_diff_turtle = nj_Kimura_corr_frac(aa_pair_distance_turtle)

fig_frac_diff_turtle = tree_frac_diff_turtle.get_figure(width=700, height=700)
fig_frac_diff_turtle.scale_bar = "top right"
fig_frac_diff_turtle.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="b683dcce-2d07-4d48-83bc-b872d919de33" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b683dcce-2d07-4d48-83bc-b872d919de33")) {                    Plotly.newPlot(                        "b683dcce-2d07-4d48-83bc-b872d919de33",                        [{"line":{"color":"black","shape":"spline","smoothing":1.3,"width":1.25},"mode":"lines","showlegend":false,"x":[null,null,0,0,null,0,0.005825582164693116,null,0.005825582164693116,0.005825582164693116,null,0.005825582164693116,0.013106605411467902,null,0.013106605411467902,0.013106605411467902,null,0.013106605411467902,0.01973493125053012,null,0.01973493125053012,0.01973493125053012,null,0.01973493125053012,0.03900793665600167,null,0.03900793665600167,0.03900793665600167,null,0.03900793665600167,0.0508457156980498,null,0.0508457156980498,0.0508457156980498,null,0.0508457156980498,0.099686394100483,null,0.0508457156980498,0.0508457156980498,null,0.0508457156980498,0.10742472006887993,null,0.03900793665600167,0.03900793665600167,null,0.03900793665600167,0.10035540133581486,null,0.01973493125053012,0.01973493125053012,null,0.01973493125053012,0.05186253972237364,null,0.05186253972237364,0.05186253972237364,null,0.05186253972237364,0.11651295144577192,null,0.05186253972237364,0.05186253972237364,null,0.05186253972237364,0.158761656829475,null,0.013106605411467902,0.013106605411467902,null,0.013106605411467902,0.036139185257053424,null,0.036139185257053424,0.036139185257053424,null,0.036139185257053424,0.048921658942739504,null,0.048921658942739504,0.048921658942739504,null,0.048921658942739504,1.0489216589427395,null,0.048921658942739504,0.048921658942739504,null,0.048921658942739504,0.08733118718345712,null,0.036139185257053424,0.036139185257053424,null,0.036139185257053424,0.056483678089479364,null,0.005825582164693116,0.005825582164693116,null,0.005825582164693116,0.020393372798203364,null,0.020393372798203364,0.020393372798203364,null,0.020393372798203364,1.0203933727982033,null,0.020393372798203364,0.020393372798203364,null,0.020393372798203364,0.031892907839416104,null,0.031892907839416104,0.031892907839416104,null,0.031892907839416104,0.03714002748319163,null,0.03714002748319163,0.03714002748319163,null,0.03714002748319163,0.03720753374120638,null,0.03714002748319163,0.03714002748319163,null,0.03714002748319163,0.04470030564269578,null,0.031892907839416104,0.031892907839416104,null,0.031892907839416104,0.053130496690314,null,0,0,null,0,0.025381744274289866,null,0.025381744274289866,0.025381744274289866,null,0.025381744274289866,0.047117814610528844,null,0.025381744274289866,0.025381744274289866,null,0.025381744274289866,0.0484382900420991,null,0,0,null,0,0.028809048945030988,null,0.028809048945030988,0.028809048945030988,null,0.028809048945030988,1.028809048945031,null,0.028809048945030988,0.028809048945030988,null,0.028809048945030988,0.04797955096935406,null],"y":[null,null,-6.5,1.0156249999999998,null,1.0156249999999998,1.0156249999999998,null,1.0156249999999998,4.14375,null,4.14375,4.14375,null,4.14375,6.6625,null,6.6625,6.6625,null,6.6625,8.125,null,8.125,8.125,null,8.125,9.100000000000001,null,9.100000000000001,9.100000000000001,null,9.100000000000001,9.75,null,9.75,9.75,null,9.100000000000001,8.450000000000001,null,8.450000000000001,8.450000000000001,null,8.125,7.15,null,7.15,7.15,null,6.6625,5.2,null,5.2,5.2,null,5.2,5.8500000000000005,null,5.8500000000000005,5.8500000000000005,null,5.2,4.55,null,4.55,4.55,null,4.14375,1.625,null,1.625,1.625,null,1.625,2.6,null,2.6,2.6,null,2.6,3.25,null,3.25,3.25,null,2.6,1.9500000000000002,null,1.9500000000000002,1.9500000000000002,null,1.625,0.65,null,0.65,0.65,null,1.0156249999999998,-2.1125000000000003,null,-2.1125000000000003,-2.1125000000000003,null,-2.11 ...

# %%
#after predict fraction identity by ani, construct tree
tree_ani_turtle = nj_Kimura_corr_ani(aa_pair_distance_turtle, aa_anis_k_4_turtle, parameters=aa_popt_cub)

fig_ani_turtle = tree_ani_turtle.get_figure(width=700, height=700)
fig_ani_turtle.scale_bar = "top right"
fig_ani_turtle.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="028235ab-87f2-48d5-9b45-012eecb06d33" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("028235ab-87f2-48d5-9b45-012eecb06d33")) {                    Plotly.newPlot(                        "028235ab-87f2-48d5-9b45-012eecb06d33",                        [{"line":{"color":"black","shape":"spline","smoothing":1.3,"width":1.25},"mode":"lines","showlegend":false,"x":[null,null,0,0,null,0,0.0031503111917136357,null,0.0031503111917136357,0.0031503111917136357,null,0.0031503111917136357,0.010296553183245235,null,0.010296553183245235,0.010296553183245235,null,0.010296553183245235,0.058799703312263224,null,0.058799703312263224,0.058799703312263224,null,0.058799703312263224,1.0587997033122631,null,0.058799703312263224,0.058799703312263224,null,0.058799703312263224,0.12087386360635245,null,0.010296553183245235,0.010296553183245235,null,0.010296553183245235,0.10548783785509114,null,0.0031503111917136357,0.0031503111917136357,null,0.0031503111917136357,0.013780455087702932,null,0.013780455087702932,0.013780455087702932,null,0.013780455087702932,0.03607733817436878,null,0.013780455087702932,0.013780455087702932,null,0.013780455087702932,0.05072101639591011,null,0.05072101639591011,0.05072101639591011,null,0.05072101639591011,0.0678969092551432,null,0.05072101639591011,0.05072101639591011,null,0.05072101639591011,0.092557494083328,null,0,0,null,0,0.004033819301706409,null,0.004033819301706409,0.004033819301706409,null,0.004033819301706409,0.025537319374556312,null,0.025537319374556312,0.025537319374556312,null,0.025537319374556312,0.04116393339699445,null,0.025537319374556312,0.025537319374556312,null,0.025537319374556312,0.1112066337112605,null,0.004033819301706409,0.004033819301706409,null,0.004033819301706409,0.028571175854775345,null,0,0,null,0,0.004597751710018175,null,0.004597751710018175,0.004597751710018175,null,0.004597751710018175,0.02429937692920168,null,0.02429937692920168,0.02429937692920168,null,0.02429937692920168,0.03520954530720519,null,0.03520954530720519,0.03520954530720519,null,0.03520954530720519,1.0352095453072052,null,0.03520954530720519,0.03520954530720519,null,0.03520954530720519,0.059512863234559205,null,0.059512863234559205,0.059512863234559205,null,0.059512863234559205,1.0595128632345592,null,0.059512863234559205,0.059512863234559205,null,0.059512863234559205,0.13368729550257985,null,0.02429937692920168,0.02429937692920168,null,0.02429937692920168,0.041004750314710875,null,0.041004750314710875,0.041004750314710875,null,0.041004750314710875,0.06884383071028105,null,0.041004750314710875,0.041004750314710875,null,0.041004750314710875,0.10018070366217918,null,0.004597751710018175,0.004597751710018175,null,0.004597751710018175,0.052480197347300785,null,0.052480197347300785,0.052480197347300785,null,0.052480197347300785,0.0871177759647542,null,0.052480197347300785,0.052480197347300785,null,0.052480197347300785,0.1555474331360003,null],"y":[null,null,0.325,6.5,null,6.5,6.5,null,6.5,8.125,null,8.125,8.125,null,8.125,9.100000000000001,null,9.100000000000001,9.100000000000001,null,9.100000000000001,9.75,null,9.75,9.75,null,9.100000000000001,8.450000000000001,null,8.450000000000001,8.450000000000001,null,8.125,7.15,null,7.15,7.15,null,6.5,4.875,null,4.875,4.875,null,4.875,5.8500000000000005,null,5.8500000000000005,5.8500000000000005,null,4.875,3.9,null,3.9,3.9,null,3.9,4.55,null,4.55,4.55,null,3.9,3.25,null,3.25,3.25,null,0.325,0.325,null,0.325,0.325,null,0.325,1.3,null,1.3,1.3,null,1.3,1.9500000000000002,null,1.9500000000000002,1.9500000000000002,null,1.3,0.65,null,0.65,0.65,null,0.325,-0.65,null,-0.65,-0.65,null,0.325,-6.906250000000001,null,-6.906250000000001,-6.906250000000001,null,-6.906250000000001,-4.7125,null,-4.7125,-4.7125,null,-4.7125,-2.925, ...
